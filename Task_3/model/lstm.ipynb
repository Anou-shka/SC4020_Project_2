# %%
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence, pad_sequence
from tqdm import tqdm
import pandas as pd
import ast

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size=2, hidden_size=64, output_size=2):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, lengths):
        # Pack the padded sequences before feeding to LSTM
        packed_input = pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)
        
        # Pass through the LSTM
        packed_output, (hn, cn) = self.lstm(packed_input)
        
        # Optionally unpack the sequence (if needed)
        unpacked_output, _ = pad_packed_sequence(packed_output, batch_first=True)
        
        # We use only the last hidden state for the output (for simplicity)
        out = self.fc(hn[-1])
        return out

# %%
cityA = pd.read_csv("../Datasets/Task 2/frequent_sequences_A.csv")
cityA = list(cityA['Pattern'])
cityA_sequence = []

for str_seq in cityA:
    tuple_seq = ast.literal_eval(str_seq)
    cityA_sequence.append(tuple_seq)

cityA_sequence
train_sequences, test_sequences = train_test_split(cityA_sequence, test_size=0.2, random_state=42)

# %%
def get_inputs_labels(dataset):
    inputs = []
    labels = []
    for seq in dataset:
        inputs.append(torch.tensor(seq[:-1], dtype=torch.float32))
        labels.append(torch.tensor(seq[-1], dtype=torch.float32))

    return inputs, labels

# %%
X_train, y_train = get_inputs_labels(train_sequences)

model = LSTMModel()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

num_epochs = 100

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0

    for seq, target in tqdm(zip(X_train, y_train), total=len(X_train), desc=f"Epoch {epoch + 1}/{num_epochs}"):       
        seq_length = torch.tensor([len(seq)])  # Length of the sequence
        padded_seq = pad_sequence([seq], batch_first=True, padding_value=0).to(torch.float32)

        # Convert target to tensor
        target = target.unsqueeze(0)  # Add batch dimension

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        output = model(padded_seq, seq_length)

        # Calculate loss
        loss = criterion(output, target)
        epoch_loss += loss.item()

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

    # Print loss for every epoch
    if (epoch + 1) % 10 == 0:
        print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {epoch_loss / len(X_train):.4f}")
        
print("Training complete.")
# Out:
# Epoch 1/100: 100%|██████████| 17815/17815 [00:30<00:00, 587.77it/s]
# Epoch 2/100: 100%|██████████| 17815/17815 [00:30<00:00, 588.30it/s]
# Epoch 3/100: 100%|██████████| 17815/17815 [00:29<00:00, 596.64it/s]
# Epoch 4/100: 100%|██████████| 17815/17815 [00:29<00:00, 608.67it/s]
# Epoch 5/100: 100%|██████████| 17815/17815 [00:29<00:00, 603.32it/s]
# Epoch 6/100: 100%|██████████| 17815/17815 [00:29<00:00, 608.81it/s]
# Epoch 7/100: 100%|██████████| 17815/17815 [00:30<00:00, 588.90it/s]
# Epoch 8/100: 100%|██████████| 17815/17815 [00:27<00:00, 640.67it/s]
# Epoch 9/100: 100%|██████████| 17815/17815 [00:27<00:00, 649.54it/s]
# Epoch 10/100: 100%|██████████| 17815/17815 [00:28<00:00, 622.74it/s]
# Epoch [10/100], Loss: 27.0909
# Epoch 11/100: 100%|██████████| 17815/17815 [00:30<00:00, 591.27it/s]
# Epoch 12/100: 100%|██████████| 17815/17815 [00:29<00:00, 605.20it/s]
# Epoch 13/100: 100%|██████████| 17815/17815 [00:28<00:00, 627.28it/s]
# Epoch 14/100: 100%|██████████| 17815/17815 [00:27<00:00, 652.21it/s]
# Epoch 15/100: 100%|██████████| 17815/17815 [00:27<00:00, 646.57it/s]
# Epoch 16/100: 100%|██████████| 17815/17815 [00:29<00:00, 610.08it/s]
# Epoch 17/100: 100%|██████████| 17815/17815 [00:28<00:00, 618.59it/s]
# Epoch 18/100: 100%|██████████| 17815/17815 [00:29<00:00, 603.43it/s]
# Epoch 19/100: 100%|██████████| 17815/17815 [00:29<00:00, 600.18it/s]
# Epoch 20/100: 100%|██████████| 17815/17815 [00:28<00:00, 629.84it/s]
# Epoch [20/100], Loss: 24.1404
# Epoch 21/100: 100%|██████████| 17815/17815 [00:30<00:00, 586.78it/s]
# Epoch 22/100: 100%|██████████| 17815/17815 [00:28<00:00, 631.51it/s]
# Epoch 23/100: 100%|██████████| 17815/17815 [00:27<00:00, 638.86it/s]
# Epoch 24/100: 100%|██████████| 17815/17815 [00:27<00:00, 644.58it/s]
# Epoch 25/100: 100%|██████████| 17815/17815 [00:30<00:00, 583.02it/s]
# Epoch 26/100: 100%|██████████| 17815/17815 [00:30<00:00, 587.94it/s]
# Epoch 27/100: 100%|██████████| 17815/17815 [00:30<00:00, 589.87it/s]
# Epoch 28/100: 100%|██████████| 17815/17815 [00:30<00:00, 575.78it/s]
# Epoch 29/100: 100%|██████████| 17815/17815 [00:29<00:00, 612.47it/s]
# Epoch 30/100: 100%|██████████| 17815/17815 [00:30<00:00, 581.69it/s]
# Epoch [30/100], Loss: 24.4113
# Epoch 31/100: 100%|██████████| 17815/17815 [00:31<00:00, 559.03it/s]
# Epoch 32/100: 100%|██████████| 17815/17815 [00:36<00:00, 485.36it/s]
# Epoch 33/100: 100%|██████████| 17815/17815 [00:35<00:00, 500.43it/s]
# Epoch 34/100: 100%|██████████| 17815/17815 [00:30<00:00, 585.89it/s]
# Epoch 35/100: 100%|██████████| 17815/17815 [00:30<00:00, 585.53it/s]
# Epoch 36/100: 100%|██████████| 17815/17815 [00:29<00:00, 600.68it/s]
# Epoch 37/100: 100%|██████████| 17815/17815 [00:29<00:00, 613.67it/s]
# Epoch 38/100: 100%|██████████| 17815/17815 [00:31<00:00, 565.62it/s]
# Epoch 39/100: 100%|██████████| 17815/17815 [00:28<00:00, 617.27it/s]
# Epoch 40/100: 100%|██████████| 17815/17815 [00:28<00:00, 625.09it/s]
# Epoch [40/100], Loss: 23.1239
# Epoch 41/100: 100%|██████████| 17815/17815 [00:27<00:00, 637.11it/s]
# Epoch 42/100: 100%|██████████| 17815/17815 [00:27<00:00, 645.24it/s]
# Epoch 43/100: 100%|██████████| 17815/17815 [00:27<00:00, 642.24it/s]
# Epoch 44/100: 100%|██████████| 17815/17815 [00:28<00:00, 626.97it/s]
# Epoch 45/100: 100%|██████████| 17815/17815 [00:30<00:00, 579.50it/s]
# Epoch 46/100: 100%|██████████| 17815/17815 [00:30<00:00, 586.47it/s]
# Epoch 47/100: 100%|██████████| 17815/17815 [00:29<00:00, 594.03it/s]
# Epoch 48/100: 100%|██████████| 17815/17815 [00:30<00:00, 591.55it/s]
# Epoch 49/100: 100%|██████████| 17815/17815 [00:29<00:00, 603.95it/s]
# Epoch 50/100: 100%|██████████| 17815/17815 [00:27<00:00, 649.39it/s]
# Epoch [50/100], Loss: 22.8884
# Epoch 51/100: 100%|██████████| 17815/17815 [00:27<00:00, 647.63it/s]
# Epoch 52/100: 100%|██████████| 17815/17815 [00:27<00:00, 653.70it/s]
# Epoch 53/100: 100%|██████████| 17815/17815 [00:28<00:00, 628.54it/s]
# Epoch 54/100: 100%|██████████| 17815/17815 [00:27<00:00, 645.49it/s]
# Epoch 55/100: 100%|██████████| 17815/17815 [00:27<00:00, 646.56it/s]
# Epoch 56/100: 100%|██████████| 17815/17815 [00:27<00:00, 647.72it/s]
# Epoch 57/100: 100%|██████████| 17815/17815 [00:27<00:00, 650.83it/s]
# Epoch 58/100: 100%|██████████| 17815/17815 [00:27<00:00, 648.69it/s]
# Epoch 59/100: 100%|██████████| 17815/17815 [00:27<00:00, 647.91it/s]
# Epoch 60/100: 100%|██████████| 17815/17815 [00:27<00:00, 648.74it/s]
# Epoch [60/100], Loss: 26.0472
# Epoch 61/100: 100%|██████████| 17815/17815 [00:27<00:00, 647.14it/s]
# Epoch 62/100: 100%|██████████| 17815/17815 [00:30<00:00, 588.03it/s]
# Epoch 63/100: 100%|██████████| 17815/17815 [00:33<00:00, 527.26it/s]
# Epoch 64/100: 100%|██████████| 17815/17815 [00:29<00:00, 601.02it/s]
# Epoch 65/100: 100%|██████████| 17815/17815 [00:29<00:00, 609.44it/s]
# Epoch 66/100: 100%|██████████| 17815/17815 [00:28<00:00, 626.52it/s]
# Epoch 67/100: 100%|██████████| 17815/17815 [00:28<00:00, 634.72it/s]
# Epoch 68/100: 100%|██████████| 17815/17815 [00:27<00:00, 644.00it/s]
# Epoch 69/100: 100%|██████████| 17815/17815 [00:27<00:00, 649.02it/s]
# Epoch 70/100: 100%|██████████| 17815/17815 [00:27<00:00, 636.69it/s]
# Epoch [70/100], Loss: 23.2294
# Epoch 71/100: 100%|██████████| 17815/17815 [00:31<00:00, 571.37it/s]
# Epoch 72/100: 100%|██████████| 17815/17815 [00:27<00:00, 636.28it/s]
# Epoch 73/100: 100%|██████████| 17815/17815 [00:27<00:00, 645.74it/s]
# Epoch 74/100: 100%|██████████| 17815/17815 [00:27<00:00, 644.25it/s]
# Epoch 75/100: 100%|██████████| 17815/17815 [00:27<00:00, 644.50it/s]
# Epoch 76/100: 100%|██████████| 17815/17815 [00:27<00:00, 636.60it/s]
# Epoch 77/100: 100%|██████████| 17815/17815 [00:28<00:00, 622.73it/s]
# Epoch 78/100: 100%|██████████| 17815/17815 [00:28<00:00, 626.37it/s]
# Epoch 79/100: 100%|██████████| 17815/17815 [00:27<00:00, 646.58it/s]
# Epoch 80/100: 100%|██████████| 17815/17815 [00:27<00:00, 648.75it/s]
# Epoch [80/100], Loss: 24.4928
# Epoch 81/100: 100%|██████████| 17815/17815 [00:27<00:00, 642.04it/s]
# Epoch 82/100: 100%|██████████| 17815/17815 [00:27<00:00, 642.49it/s]
# Epoch 83/100: 100%|██████████| 17815/17815 [00:27<00:00, 645.70it/s]
# Epoch 84/100: 100%|██████████| 17815/17815 [00:27<00:00, 648.52it/s]
# Epoch 85/100: 100%|██████████| 17815/17815 [00:27<00:00, 648.65it/s]
# Epoch 86/100: 100%|██████████| 17815/17815 [00:27<00:00, 644.66it/s]
# Epoch 87/100: 100%|██████████| 17815/17815 [00:27<00:00, 649.29it/s]
# Epoch 88/100: 100%|██████████| 17815/17815 [00:27<00:00, 647.92it/s]
# Epoch 89/100: 100%|██████████| 17815/17815 [00:27<00:00, 652.69it/s]
# Epoch 90/100: 100%|██████████| 17815/17815 [00:27<00:00, 655.13it/s]
# Epoch [90/100], Loss: 24.6480
# Epoch 91/100: 100%|██████████| 17815/17815 [00:27<00:00, 647.73it/s]
# Epoch 92/100: 100%|██████████| 17815/17815 [00:27<00:00, 648.51it/s]
# Epoch 93/100: 100%|██████████| 17815/17815 [00:27<00:00, 651.10it/s]
# Epoch 94/100: 100%|██████████| 17815/17815 [00:27<00:00, 654.56it/s]
# Epoch 95/100: 100%|██████████| 17815/17815 [00:27<00:00, 649.72it/s]
# Epoch 96/100: 100%|██████████| 17815/17815 [00:27<00:00, 653.15it/s]
# Epoch 97/100: 100%|██████████| 17815/17815 [00:28<00:00, 633.47it/s]
# Epoch 98/100: 100%|██████████| 17815/17815 [00:27<00:00, 647.63it/s]
# Epoch 99/100: 100%|██████████| 17815/17815 [00:28<00:00, 627.44it/s]
# Epoch 100/100: 100%|██████████| 17815/17815 [00:27<00:00, 637.75it/s]
# Epoch [100/100], Loss: 22.9910
# Training complete.

# %%
torch.save(model.state_dict(), "lstm_model.pth")
print('saved to lstm_model.pth')
# Out:
# saved to lstm_model.pth

# %%
X_test, y_test = get_inputs_labels(test_sequences)

model.eval()
predictions = []

with torch.no_grad():
    for seq in X_test:
        # Prepare sequence
        seq_length = torch.tensor([len(seq)])  # Sequence length
        padded_seq = pad_sequence([seq], batch_first=True).float()  # Convert to float if needed

        # Forward pass to get the prediction
        pred = model(padded_seq, seq_length)
        predictions.append(pred.squeeze().cpu())  # Append the prediction, removing extra dimensions

# Display predictions and compare to true targets
for i, (pred, true_target) in enumerate(zip(predictions, y_test)):
    print(f"Test Sequence {i+1}:")
    print(f"  Predicted next coordinate: {pred.numpy()}")
    print(f"  True next coordinate: {true_target.numpy()}")
# Out:
# Test Sequence 1:
#   Predicted next coordinate: [176.1075  45.214 ]
#   True next coordinate: [176.  48.]
# Test Sequence 2:
#   Predicted next coordinate: [ 54.77323 168.20311]
#   True next coordinate: [ 56. 168.]
# Test Sequence 3:
#   Predicted next coordinate: [ 18.27745 109.11273]
#   True next coordinate: [ 24. 111.]
# Test Sequence 4:
#   Predicted next coordinate: [ 96.6445 110.6371]
#   True next coordinate: [ 97. 111.]
# Test Sequence 5:
#   Predicted next coordinate: [ 1.5959778 34.46978  ]
#   True next coordinate: [ 1. 33.]
# Test Sequence 6:
#   Predicted next coordinate: [117.64739  96.80162]
#   True next coordinate: [117. 101.]
# Test Sequence 7:
#   Predicted next coordinate: [182.91556 103.50127]
#   True next coordinate: [183. 104.]
# Test Sequence 8:
#   Predicted next coordinate: [143.89758   88.020996]
#   True next coordinate: [142.  90.]
# Test Sequence 9:
#   Predicted next coordinate: [157.70715   37.794777]
#   True next coordinate: [156.  40.]
# Test Sequence 10:
#   Predicted next coordinate: [ 76.88026 100.50473]
#   True next coordinate: [ 79. 102.]
# Test Sequence 11:
#   Predicted next coordinate: [137.41841   55.819695]
#   True next coordinate: [136.  58.]
# Test Sequence 12:
#   Predicted next coordinate: [141.8186   88.08525]
#   True next coordinate: [141.  90.]
# Test Sequence 13:
#   Predicted next coordinate: [102.806854  32.017635]
#   True next coordinate: [103.  29.]
# Test Sequence 14:
#   Predicted next coordinate: [100.80792 110.51355]
#   True next coordinate: [101. 110.]
# Test Sequence 15:
#   Predicted next coordinate: [175.95282 176.37498]
#   True next coordinate: [195. 184.]
# Test Sequence 16:
#   Predicted next coordinate: [171.95248   54.469772]
#   True next coordinate: [170.  56.]
# Test Sequence 17:
#   Predicted next coordinate: [176.30908 118.70456]
#   True next coordinate: [175. 115.]
# Test Sequence 18:
#   Predicted next coordinate: [185.97314   30.168402]
#   True next coordinate: [181.  38.]
# Test Sequence 19:
#   Predicted next coordinate: [129.19684  74.5735 ]
#   True next coordinate: [131.  76.]
# Test Sequence 20:
#   Predicted next coordinate: [168.96631   36.647194]
#   True next coordinate: [166.  41.]
# Test Sequence 21:
#   Predicted next coordinate: [144.77808  78.64267]
#   True next coordinate: [146.  81.]
# Test Sequence 22:
#   Predicted next coordinate: [ 68.91079 186.35199]
#   True next coordinate: [ 67. 187.]
# Test Sequence 23:
#   Predicted next coordinate: [176.9837    16.850565]
#   True next coordinate: [172.  24.]
# Test Sequence 24:
#   Predicted next coordinate: [151.91917  38.22993]
#   True next coordinate: [151.  45.]
# Test Sequence 25:
#   Predicted next coordinate: [152.98553  89.88594]
#   True next coordinate: [161.  97.]
# Test Sequence 26:
#   Predicted next coordinate: [14.68075  26.458412]
#   True next coordinate: [16. 26.]
# Test Sequence 27:
#   Predicted next coordinate: [78.127144 84.5161  ]
#   True next coordinate: [79. 82.]
# Test Sequence 28:
#   Predicted next coordinate: [89.384186 23.145105]
#   True next coordinate: [91. 20.]
# Test Sequence 29:
#   Predicted next coordinate: [160.43414  82.75125]
#   True next coordinate: [158.  83.]
# Test Sequence 30:
#   Predicted next coordinate: [117.17231 113.67241]
#   True next coordinate: [119. 116.]
# Test Sequence 31:
#   Predicted next coordinate: [161.60178 106.46756]
#   True next coordinate: [158. 105.]
# Test Sequence 32:
#   Predicted next coordinate: [185.10503 113.36276]
#   True next coordinate: [186. 113.]
# Test Sequence 33:
#   Predicted next coordinate: [77.45497 73.71379]
#   True next coordinate: [76. 69.]
# Test Sequence 34:
#   Predicted next coordinate: [100.83019   77.639114]
#   True next coordinate: [99. 78.]
# Test Sequence 35:
#   Predicted next coordinate: [ 78.14299 104.2937 ]
#   True next coordinate: [ 83. 107.]
# Test Sequence 36:
#   Predicted next coordinate: [ 94.91781 141.09972]
#   True next coordinate: [101. 139.]
# Test Sequence 37:
#   Predicted next coordinate: [ 59.128426 178.28929 ]
#   True next coordinate: [ 59. 181.]
# Test Sequence 38:
#   Predicted next coordinate: [149.2545   93.34938]
#   True next coordinate: [148.  95.]
# Test Sequence 39:
#   Predicted next coordinate: [81.00777 98.78688]
#   True next coordinate: [ 81. 101.]
# Test Sequence 40:
#   Predicted next coordinate: [86.986664 92.92253 ]
#   True next coordinate: [88. 99.]
# Test Sequence 41:
#   Predicted next coordinate: [ 68.84003  102.440445]
#   True next coordinate: [ 70. 103.]
# Test Sequence 42:
#   Predicted next coordinate: [ 63.445175 104.55899 ]
#   True next coordinate: [ 63. 107.]
# Test Sequence 43:
#   Predicted next coordinate: [142.32657  92.90933]
#   True next coordinate: [142.  93.]
# Test Sequence 44:
#   Predicted next coordinate: [123.20091  99.20982]
#   True next coordinate: [122. 102.]
# Test Sequence 45:
#   Predicted next coordinate: [ 64.54771 133.7452 ]
#   True next coordinate: [ 69. 134.]
# Test Sequence 46:
#   Predicted next coordinate: [136.80235  80.91832]
#   True next coordinate: [137.  81.]
# Test Sequence 47:
#   Predicted next coordinate: [174.94838   12.716362]
#   True next coordinate: [170.  19.]
# Test Sequence 48:
#   Predicted next coordinate: [143.28261  46.40536]
#   True next coordinate: [140.  50.]
# Test Sequence 49:
#   Predicted next coordinate: [129.13922 108.5184 ]
#   True next coordinate: [128. 113.]
# Test Sequence 50:
#   Predicted next coordinate: [81.5995   22.167933]
#   True next coordinate: [83. 18.]
# Test Sequence 51:
#   Predicted next coordinate: [168.19206  76.83185]
#   True next coordinate: [165.  75.]
# Test Sequence 52:
#   Predicted next coordinate: [60.99861    6.0435467]
#   True next coordinate: [64.  3.]
# Test Sequence 53:
#   Predicted next coordinate: [139.66919   26.208467]
#   True next coordinate: [136.  25.]
# Test Sequence 54:
#   Predicted next coordinate: [174.90271 177.18279]
#   True next coordinate: [191. 184.]
# Test Sequence 55:
#   Predicted next coordinate: [153.2131    43.660217]
#   True next coordinate: [152.  48.]
# Test Sequence 56:
#   Predicted next coordinate: [ 88.48406  125.442276]
#   True next coordinate: [ 94. 126.]
# Test Sequence 57:
#   Predicted next coordinate: [114.12527  62.0138 ]
#   True next coordinate: [113.  62.]
# Test Sequence 58:
#   Predicted next coordinate: [ 36.76147 173.98187]
#   True next coordinate: [ 40. 175.]
# Test Sequence 59:
#   Predicted next coordinate: [169.12215 136.51086]
#   True next coordinate: [167. 127.]
# Test Sequence 60:
#   Predicted next coordinate: [157.83377   51.215748]
#   True next coordinate: [157.  55.]
# Test Sequence 61:
#   Predicted next coordinate: [14.447618 20.194977]
#   True next coordinate: [12. 22.]
# Test Sequence 62:
#   Predicted next coordinate: [105.95644   20.597061]
#   True next coordinate: [107.   7.]
# Test Sequence 63:
#   Predicted next coordinate: [163.70967 138.34117]
#   True next coordinate: [163. 140.]
# Test Sequence 64:
#   Predicted next coordinate: [ 70.664314 137.16936 ]
#   True next coordinate: [ 74. 134.]
# Test Sequence 65:
#   Predicted next coordinate: [180.41791 198.94882]
#   True next coordinate: [197. 200.]
# Test Sequence 66:
#   Predicted next coordinate: [164.09932  85.51453]
#   True next coordinate: [161.  86.]
# Test Sequence 67:
#   Predicted next coordinate: [140.03806 101.95859]
#   True next coordinate: [142. 104.]
# Test Sequence 68:
#   Predicted next coordinate: [ 88.927895 100.92529 ]
#   True next coordinate: [ 89. 102.]
# Test Sequence 69:
#   Predicted next coordinate: [103.54637  92.05022]
#   True next coordinate: [105.  94.]
# Test Sequence 70:
#   Predicted next coordinate: [130.5471    79.235214]
#   True next coordinate: [129.  80.]
# Test Sequence 71:
#   Predicted next coordinate: [104.39101   37.745274]
#   True next coordinate: [102.  32.]
# Test Sequence 72:
#   Predicted next coordinate: [147.84766  33.06398]
#   True next coordinate: [144.  35.]
# Test Sequence 73:
#   Predicted next coordinate: [188.75389  88.62486]
#   True next coordinate: [193.  88.]
# Test Sequence 74:
#   Predicted next coordinate: [148.08827  99.90584]
#   True next coordinate: [151.  99.]
# Test Sequence 75:
#   Predicted next coordinate: [86.84769 91.40607]
#   True next coordinate: [88. 93.]
# Test Sequence 76:
#   Predicted next coordinate: [97.62135 72.44932]
#   True next coordinate: [94. 72.]
# Test Sequence 77:
#   Predicted next coordinate: [73.69322  21.991573]
#   True next coordinate: [75. 20.]
# Test Sequence 78:
#   Predicted next coordinate: [79.73171 71.38428]
#   True next coordinate: [80. 69.]
# Test Sequence 79:
#   Predicted next coordinate: [104.52533   78.519005]
#   True next coordinate: [103.  79.]
# Test Sequence 80:
#   Predicted next coordinate: [ 88.393906 123.02255 ]
#   True next coordinate: [ 93. 125.]
# Test Sequence 81:
#   Predicted next coordinate: [ 60.363724 139.57242 ]
#   True next coordinate: [ 65. 141.]
# Test Sequence 82:
#   Predicted next coordinate: [182.6228    52.344913]
#   True next coordinate: [182.  55.]
# Test Sequence 83:
#   Predicted next coordinate: [ 58.68779 171.36523]
#   True next coordinate: [ 61. 173.]
# Test Sequence 84:
#   Predicted next coordinate: [58.22803    6.7779655]
#   True next coordinate: [61.  4.]
# Test Sequence 85:
#   Predicted next coordinate: [ 88.72978 138.96036]
#   True next coordinate: [ 93. 135.]
# Test Sequence 86:
#   Predicted next coordinate: [83.92767  88.776505]
#   True next coordinate: [86. 89.]
# Test Sequence 87:
#   Predicted next coordinate: [101.28755 119.99603]
#   True next coordinate: [103. 119.]
# Test Sequence 88:
#   Predicted next coordinate: [164.6415 138.9947]
#   True next coordinate: [161. 132.]
# Test Sequence 89:
#   Predicted next coordinate: [128.88094 100.64192]
#   True next coordinate: [131. 101.]
# Test Sequence 90:
#   Predicted next coordinate: [140.81879 105.54384]
#   True next coordinate: [143. 106.]
# Test Sequence 91:
#   Predicted next coordinate: [146.64464  73.74092]
#   True next coordinate: [146.  73.]
# Test Sequence 92:
#   Predicted next coordinate: [173.0134    58.232353]
#   True next coordinate: [172.  61.]
# Test Sequence 93:
#   Predicted next coordinate: [ 21.763622 134.78903 ]
#   True next coordinate: [ 28. 132.]
# Test Sequence 94:
#   Predicted next coordinate: [18.883335  3.019823]
#   True next coordinate: [17.  5.]
# Test Sequence 95:
#   Predicted next coordinate: [106.701805  82.96065 ]
#   True next coordinate: [106.  84.]
# Test Sequence 96:
#   Predicted next coordinate: [ 67.80957 184.60446]
#   True next coordinate: [ 69. 186.]
# Test Sequence 97:
#   Predicted next coordinate: [143.901    87.05412]
#   True next coordinate: [142.  89.]
# Test Sequence 98:
#   Predicted next coordinate: [17.67953   5.176544]
#   True next coordinate: [17.  6.]
# Test Sequence 99:
#   Predicted next coordinate: [146.75514   77.115875]
#   True next coordinate: [146.  77.]
# Test Sequence 100:
#   Predicted next coordinate: [147.00372  100.670654]
#   True next coordinate: [148. 100.]
# Test Sequence 101:
#   Predicted next coordinate: [161.02553   15.945183]
#   True next coordinate: [155.  20.]
# Test Sequence 102:
#   Predicted next coordinate: [115.77387 124.1897 ]
#   True next coordinate: [116. 126.]
# Test Sequence 103:
#   Predicted next coordinate: [104.24389   23.240232]
#   True next coordinate: [98. 20.]
# Test Sequence 104:
#   Predicted next coordinate: [192.7122   23.46687]
#   True next coordinate: [189.  32.]
# Test Sequence 105:
#   Predicted next coordinate: [82.85906  92.600296]
#   True next coordinate: [83. 94.]
# Test Sequence 106:
#   Predicted next coordinate: [189.67116  76.67975]
#   True next coordinate: [199.  75.]
# Test Sequence 107:
#   Predicted next coordinate: [ 99.413895 113.746216]
#   True next coordinate: [100. 113.]
# Test Sequence 108:
#   Predicted next coordinate: [ 98.68168 138.9809 ]
#   True next coordinate: [104. 137.]
# Test Sequence 109:
#   Predicted next coordinate: [146.33131   40.923378]
#   True next coordinate: [144.  44.]
# Test Sequence 110:
#   Predicted next coordinate: [141.39407  -2.91399]
#   True next coordinate: [133.   2.]
# Test Sequence 111:
#   Predicted next coordinate: [115.32568  82.90949]
#   True next coordinate: [115.  82.]
# Test Sequence 112:
#   Predicted next coordinate: [116.09954 129.01572]
#   True next coordinate: [118. 127.]
# Test Sequence 113:
#   Predicted next coordinate: [118.00426  88.86784]
#   True next coordinate: [118.  89.]
# Test Sequence 114:
#   Predicted next coordinate: [168.11037 128.26149]
#   True next coordinate: [169. 127.]
# Test Sequence 115:
#   Predicted next coordinate: [100.295876   7.397089]
#   True next coordinate: [97.  6.]
# Test Sequence 116:
#   Predicted next coordinate: [ 33.852333 169.07437 ]
#   True next coordinate: [ 41. 173.]
# Test Sequence 117:
#   Predicted next coordinate: [104.581985 112.94084 ]
#   True next coordinate: [106. 114.]
# Test Sequence 118:
#   Predicted next coordinate: [97.97402 76.97507]
#   True next coordinate: [96. 77.]
# Test Sequence 119:
#   Predicted next coordinate: [123.62463 141.09914]
#   True next coordinate: [123. 136.]
# Test Sequence 120:
#   Predicted next coordinate: [174.95465   8.75794]
#   True next coordinate: [174.   5.]
# Test Sequence 121:
#   Predicted next coordinate: [171.78885   19.807634]
#   True next coordinate: [165.  26.]
# Test Sequence 122:
#   Predicted next coordinate: [147.65611   63.262245]
#   True next coordinate: [146.  64.]
# Test Sequence 123:
#   Predicted next coordinate: [ 33.489563 154.83838 ]
#   True next coordinate: [ 35. 152.]
# Test Sequence 124:
#   Predicted next coordinate: [118.86018 136.02213]
#   True next coordinate: [118. 132.]
# Test Sequence 125:
#   Predicted next coordinate: [114.57946  90.58246]
#   True next coordinate: [116.  92.]
# Test Sequence 126:
#   Predicted next coordinate: [148.11375  84.48071]
#   True next coordinate: [147.  86.]
# Test Sequence 127:
#   Predicted next coordinate: [123.09673 180.57658]
#   True next coordinate: [124. 165.]
# Test Sequence 128:
#   Predicted next coordinate: [ 66.64478 167.36342]
#   True next coordinate: [ 69. 164.]
# Test Sequence 129:
#   Predicted next coordinate: [ 4.974001 28.487236]
#   True next coordinate: [ 7. 27.]
# Test Sequence 130:
#   Predicted next coordinate: [194.07088   18.259758]
#   True next coordinate: [194.  26.]
# Test Sequence 131:
#   Predicted next coordinate: [ 64.86411 176.90634]
#   True next coordinate: [ 66. 176.]
# Test Sequence 132:
#   Predicted next coordinate: [175.51875 176.6791 ]
#   True next coordinate: [192. 182.]
# Test Sequence 133:
#   Predicted next coordinate: [ 69.66636 115.62126]
#   True next coordinate: [ 70. 117.]
# Test Sequence 134:
#   Predicted next coordinate: [117.59977  94.58476]
#   True next coordinate: [118.  96.]
# Test Sequence 135:
#   Predicted next coordinate: [174.80682 175.88542]
#   True next coordinate: [182. 172.]
# Test Sequence 136:
#   Predicted next coordinate: [ 87.8264  107.95537]
#   True next coordinate: [ 88. 109.]
# Test Sequence 137:
#   Predicted next coordinate: [171.65385   17.678833]
#   True next coordinate: [166.  24.]
# Test Sequence 138:
#   Predicted next coordinate: [109.1829  121.38196]
#   True next coordinate: [111. 121.]
# Test Sequence 139:
#   Predicted next coordinate: [96.20208  84.153786]
#   True next coordinate: [96. 85.]
# Test Sequence 140:
#   Predicted next coordinate: [184.47658   13.561855]
#   True next coordinate: [183.  17.]
# Test Sequence 141:
#   Predicted next coordinate: [194.01308   52.597538]
#   True next coordinate: [194.  54.]
# Test Sequence 142:
#   Predicted next coordinate: [120.75747  100.908066]
#   True next coordinate: [121. 104.]
# Test Sequence 143:
#   Predicted next coordinate: [169.97049   41.370216]
#   True next coordinate: [171.  46.]
# Test Sequence 144:
#   Predicted next coordinate: [151.72406  87.99804]
#   True next coordinate: [150.  91.]
# Test Sequence 145:
#   Predicted next coordinate: [ 53.886112 168.04376 ]
#   True next coordinate: [ 55. 169.]
# Test Sequence 146:
#   Predicted next coordinate: [85.52162 93.27065]
#   True next coordinate: [86. 97.]
# Test Sequence 147:
#   Predicted next coordinate: [154.05762   87.131874]
#   True next coordinate: [150.  88.]
# Test Sequence 148:
#   Predicted next coordinate: [185.328    82.36609]
#   True next coordinate: [185.  82.]
# Test Sequence 149:
#   Predicted next coordinate: [156.45222  69.04736]
#   True next coordinate: [155.  68.]
# Test Sequence 150:
#   Predicted next coordinate: [145.21638  117.482864]
#   True next coordinate: [145. 120.]
# Test Sequence 151:
#   Predicted next coordinate: [161.06712  64.48003]
#   True next coordinate: [159.  66.]
# Test Sequence 152:
#   Predicted next coordinate: [182.82779   37.246944]
#   True next coordinate: [178.  45.]
# Test Sequence 153:
#   Predicted next coordinate: [127.99847  79.74027]
#   True next coordinate: [126.  81.]
# Test Sequence 154:
#   Predicted next coordinate: [135.71298  79.35295]
#   True next coordinate: [135.  81.]
# Test Sequence 155:
#   Predicted next coordinate: [ 88.182175 118.732346]
#   True next coordinate: [ 94. 119.]
# Test Sequence 156:
#   Predicted next coordinate: [85.22291 97.87067]
#   True next coordinate: [ 85. 100.]
# Test Sequence 157:
#   Predicted next coordinate: [174.53378 176.29791]
#   True next coordinate: [182. 172.]
# Test Sequence 158:
#   Predicted next coordinate: [ 59.13163 167.63625]
#   True next coordinate: [ 61. 167.]
# Test Sequence 159:
#   Predicted next coordinate: [176.40335  10.64127]
#   True next coordinate: [174.  16.]
# Test Sequence 160:
#   Predicted next coordinate: [148.08751   44.222267]
#   True next coordinate: [146.  49.]
# Test Sequence 161:
#   Predicted next coordinate: [172.69626  76.68312]
#   True next coordinate: [169.  75.]
# Test Sequence 162:
#   Predicted next coordinate: [138.34627   27.261826]
#   True next coordinate: [135.  25.]
# Test Sequence 163:
#   Predicted next coordinate: [175.77931 176.52591]
#   True next coordinate: [195. 184.]
# Test Sequence 164:
#   Predicted next coordinate: [ 16.24024 148.03848]
#   True next coordinate: [ 27. 151.]
# Test Sequence 165:
#   Predicted next coordinate: [186.72229 107.27673]
#   True next coordinate: [190. 107.]
# Test Sequence 166:
#   Predicted next coordinate: [124.81614   45.426094]
#   True next coordinate: [124.  46.]
# Test Sequence 167:
#   Predicted next coordinate: [162.55774   50.570026]
#   True next coordinate: [163.  55.]
# Test Sequence 168:
#   Predicted next coordinate: [45.245644  4.744753]
#   True next coordinate: [44.  5.]
# Test Sequence 169:
#   Predicted next coordinate: [183.66968  68.50156]
#   True next coordinate: [182.  69.]
# Test Sequence 170:
#   Predicted next coordinate: [ 65.38305 167.55049]
#   True next coordinate: [ 68. 166.]
# Test Sequence 171:
#   Predicted next coordinate: [118.257355  20.383919]
#   True next coordinate: [111.  19.]
# Test Sequence 172:
#   Predicted next coordinate: [118.805405  92.54701 ]
#   True next coordinate: [120.  93.]
# Test Sequence 173:
#   Predicted next coordinate: [133.39435   12.248747]
#   True next coordinate: [132.  11.]
# Test Sequence 174:
#   Predicted next coordinate: [118.84665   93.242165]
#   True next coordinate: [120.  94.]
# Test Sequence 175:
#   Predicted next coordinate: [105.37995 141.88431]
#   True next coordinate: [107. 139.]
# Test Sequence 176:
#   Predicted next coordinate: [139.85461  87.10754]
#   True next coordinate: [139.  89.]
# Test Sequence 177:
#   Predicted next coordinate: [106.742874  82.19502 ]
#   True next coordinate: [106.  82.]
# Test Sequence 178:
#   Predicted next coordinate: [142.51285  73.85022]
#   True next coordinate: [142.  73.]
# Test Sequence 179:
#   Predicted next coordinate: [ 97.04885  116.660034]
#   True next coordinate: [ 96. 118.]
# Test Sequence 180:
#   Predicted next coordinate: [153.21474   44.461277]
#   True next coordinate: [152.  49.]
# Test Sequence 181:
#   Predicted next coordinate: [140.53816   50.331192]
#   True next coordinate: [138.  55.]
# Test Sequence 182:
#   Predicted next coordinate: [120.60018  97.90169]
#   True next coordinate: [121. 101.]
# Test Sequence 183:
#   Predicted next coordinate: [140.71414    8.972767]
#   True next coordinate: [133.  11.]
# Test Sequence 184:
#   Predicted next coordinate: [108.96285  100.503815]
#   True next coordinate: [111. 102.]
# Test Sequence 185:
#   Predicted next coordinate: [ 96.18651 122.19815]
#   True next coordinate: [ 98. 123.]
# Test Sequence 186:
#   Predicted next coordinate: [187.01033  15.10413]
#   True next coordinate: [185.  20.]
# Test Sequence 187:
#   Predicted next coordinate: [ 84.1606  137.51431]
#   True next coordinate: [ 86. 135.]
# Test Sequence 188:
#   Predicted next coordinate: [139.46362  74.42313]
#   True next coordinate: [141.  75.]
# Test Sequence 189:
#   Predicted next coordinate: [127.204666  26.501038]
#   True next coordinate: [125.  24.]
# Test Sequence 190:
#   Predicted next coordinate: [ 77.84705 192.3276 ]
#   True next coordinate: [ 79. 194.]
# Test Sequence 191:
#   Predicted next coordinate: [ 27.117311 145.25177 ]
#   True next coordinate: [ 32. 141.]
# Test Sequence 192:
#   Predicted next coordinate: [185.9804    26.985357]
#   True next coordinate: [181.  35.]
# Test Sequence 193:
#   Predicted next coordinate: [ 7.8664875 12.909706 ]
#   True next coordinate: [ 8. 15.]
# Test Sequence 194:
#   Predicted next coordinate: [112.19516  46.70146]
#   True next coordinate: [112.  44.]
# Test Sequence 195:
#   Predicted next coordinate: [146.72565     1.4601212]
#   True next coordinate: [139.   6.]
# Test Sequence 196:
#   Predicted next coordinate: [173.52417  79.76628]
#   True next coordinate: [170.  79.]
# Test Sequence 197:
#   Predicted next coordinate: [148.08751   44.222267]
#   True next coordinate: [145.  47.]
# Test Sequence 198:
#   Predicted next coordinate: [173.70221    8.341545]
#   True next coordinate: [174.   7.]
# Test Sequence 199:
#   Predicted next coordinate: [53.688454  4.473774]
#   True next coordinate: [44.  5.]
# Test Sequence 200:
#   Predicted next coordinate: [153.83026   38.167774]
#   True next coordinate: [151.  44.]
# Test Sequence 201:
#   Predicted next coordinate: [135.53429  107.935196]
#   True next coordinate: [136. 110.]
# Test Sequence 202:
#   Predicted next coordinate: [122.48403   63.879303]
#   True next coordinate: [123.  62.]
# Test Sequence 203:
#   Predicted next coordinate: [147.22685  43.33133]
#   True next coordinate: [146.  48.]
# Test Sequence 204:
#   Predicted next coordinate: [93.49695  31.814661]
#   True next coordinate: [91. 26.]
# Test Sequence 205:
#   Predicted next coordinate: [133.4799    47.859074]
#   True next coordinate: [135.  48.]
# Test Sequence 206:
#   Predicted next coordinate: [165.87161  75.80687]
#   True next coordinate: [163.  75.]
# Test Sequence 207:
#   Predicted next coordinate: [129.58972  78.29936]
#   True next coordinate: [128.  79.]
# Test Sequence 208:
#   Predicted next coordinate: [ 33.489563 154.83838 ]
#   True next coordinate: [ 34. 151.]
# Test Sequence 209:
#   Predicted next coordinate: [ 79.84853 129.63213]
#   True next coordinate: [ 85. 129.]
# Test Sequence 210:
#   Predicted next coordinate: [152.23564   56.810265]
#   True next coordinate: [150.  61.]
# Test Sequence 211:
#   Predicted next coordinate: [ 86.51766 142.89795]
#   True next coordinate: [ 89. 139.]
# Test Sequence 212:
#   Predicted next coordinate: [140.9775   40.31977]
#   True next coordinate: [140.  44.]
# Test Sequence 213:
#   Predicted next coordinate: [132.78674  77.57795]
#   True next coordinate: [131.  78.]
# Test Sequence 214:
#   Predicted next coordinate: [97.41039  32.776054]
#   True next coordinate: [95. 26.]
# Test Sequence 215:
#   Predicted next coordinate: [168.0603   84.50371]
#   True next coordinate: [166.  84.]
# Test Sequence 216:
#   Predicted next coordinate: [184.60065  69.84219]
#   True next coordinate: [185.  69.]
# Test Sequence 217:
#   Predicted next coordinate: [192.51685   39.441032]
#   True next coordinate: [191.  49.]
# Test Sequence 218:
#   Predicted next coordinate: [121.33153   71.505196]
#   True next coordinate: [118.  72.]
# Test Sequence 219:
#   Predicted next coordinate: [144.37782    -3.8164978]
#   True next coordinate: [133.   1.]
# Test Sequence 220:
#   Predicted next coordinate: [ 58.247368 168.24376 ]
#   True next coordinate: [ 60. 168.]
# Test Sequence 221:
#   Predicted next coordinate: [129.58972  78.29936]
#   True next coordinate: [128.  80.]
# Test Sequence 222:
#   Predicted next coordinate: [113.19377   28.439335]
#   True next coordinate: [107.  27.]
# Test Sequence 223:
#   Predicted next coordinate: [187.93158 100.11043]
#   True next coordinate: [192. 101.]
# Test Sequence 224:
#   Predicted next coordinate: [165.16167   42.361397]
#   True next coordinate: [163.  46.]
# Test Sequence 225:
#   Predicted next coordinate: [70.601166 82.980316]
#   True next coordinate: [68. 79.]
# Test Sequence 226:
#   Predicted next coordinate: [ 81.765564 133.5596  ]
#   True next coordinate: [ 83. 131.]
# Test Sequence 227:
#   Predicted next coordinate: [148.04173  82.8153 ]
#   True next coordinate: [147.  84.]
# Test Sequence 228:
#   Predicted next coordinate: [132.1597   72.67064]
#   True next coordinate: [134.  74.]
# Test Sequence 229:
#   Predicted next coordinate: [148.64378  70.80682]
#   True next coordinate: [147.  69.]
# Test Sequence 230:
#   Predicted next coordinate: [111.6845   101.259445]
#   True next coordinate: [114. 106.]
# Test Sequence 231:
#   Predicted next coordinate: [68.5419   18.157724]
#   True next coordinate: [69. 18.]
# Test Sequence 232:
#   Predicted next coordinate: [ 1.6016808 33.67872  ]
#   True next coordinate: [ 2. 33.]
# Test Sequence 233:
#   Predicted next coordinate: [177.64435   60.869568]
#   True next coordinate: [177.  61.]
# Test Sequence 234:
#   Predicted next coordinate: [108.22182   50.164845]
#   True next coordinate: [109.  46.]
# Test Sequence 235:
#   Predicted next coordinate: [183.12596  115.291306]
#   True next coordinate: [183. 115.]
# Test Sequence 236:
#   Predicted next coordinate: [113.48802   11.042961]
#   True next coordinate: [106.   6.]
# Test Sequence 237:
#   Predicted next coordinate: [ 72.35354 143.82486]
#   True next coordinate: [ 83. 145.]
# Test Sequence 238:
#   Predicted next coordinate: [75.91998  16.948853]
#   True next coordinate: [79. 14.]
# Test Sequence 239:
#   Predicted next coordinate: [ 61.896515 165.67436 ]
#   True next coordinate: [ 64. 164.]
# Test Sequence 240:
#   Predicted next coordinate: [ 92.57693 101.71471]
#   True next coordinate: [ 93. 103.]
# Test Sequence 241:
#   Predicted next coordinate: [153.24438 101.46481]
#   True next coordinate: [152. 108.]
# Test Sequence 242:
#   Predicted next coordinate: [104.95766 123.17445]
#   True next coordinate: [106. 123.]
# Test Sequence 243:
#   Predicted next coordinate: [131.18623   5.15399]
#   True next coordinate: [122.   6.]
# Test Sequence 244:
#   Predicted next coordinate: [76.28449  25.943676]
#   True next coordinate: [76. 26.]
# Test Sequence 245:
#   Predicted next coordinate: [102.63368  92.80301]
#   True next coordinate: [103.  96.]
# Test Sequence 246:
#   Predicted next coordinate: [ 12.105919 111.95395 ]
#   True next coordinate: [ 18. 106.]
# Test Sequence 247:
#   Predicted next coordinate: [97.83977 74.37533]
#   True next coordinate: [94. 74.]
# Test Sequence 248:
#   Predicted next coordinate: [181.42142 103.028  ]
#   True next coordinate: [180. 104.]
# Test Sequence 249:
#   Predicted next coordinate: [156.11327  36.29436]
#   True next coordinate: [154.  38.]
# Test Sequence 250:
#   Predicted next coordinate: [171.58946  89.51021]
#   True next coordinate: [170.  90.]
# Test Sequence 251:
#   Predicted next coordinate: [94.96979 24.50389]
#   True next coordinate: [94. 19.]
# Test Sequence 252:
#   Predicted next coordinate: [173.3975  162.79182]
#   True next coordinate: [172. 151.]
# Test Sequence 253:
#   Predicted next coordinate: [127.28493  71.36102]
#   True next coordinate: [128.  70.]
# Test Sequence 254:
#   Predicted next coordinate: [133.12048  81.76289]
#   True next coordinate: [135.  82.]
# Test Sequence 255:
#   Predicted next coordinate: [194.66887  34.63108]
#   True next coordinate: [192.  45.]
# Test Sequence 256:
#   Predicted next coordinate: [109.82991 131.03418]
#   True next coordinate: [112. 132.]
# Test Sequence 257:
#   Predicted next coordinate: [109.88441   91.265274]
#   True next coordinate: [110.  93.]
# Test Sequence 258:
#   Predicted next coordinate: [ 49.80893 179.2117 ]
#   True next coordinate: [ 51. 183.]
# Test Sequence 259:
#   Predicted next coordinate: [120.28966  86.64485]
#   True next coordinate: [121.  86.]
# Test Sequence 260:
#   Predicted next coordinate: [130.51337  74.55887]
#   True next coordinate: [131.  78.]
# Test Sequence 261:
#   Predicted next coordinate: [116.66503  44.23691]
#   True next coordinate: [117.  43.]
# Test Sequence 262:
#   Predicted next coordinate: [109.77546  31.41275]
#   True next coordinate: [111.  29.]
# Test Sequence 263:
#   Predicted next coordinate: [ 83.26454 141.37398]
#   True next coordinate: [ 86. 138.]
# Test Sequence 264:
#   Predicted next coordinate: [ 81.81865 104.59273]
#   True next coordinate: [ 84. 105.]
# Test Sequence 265:
#   Predicted next coordinate: [163.31517  61.15326]
#   True next coordinate: [163.  64.]
# Test Sequence 266:
#   Predicted next coordinate: [109.011185 148.02525 ]
#   True next coordinate: [112. 143.]
# Test Sequence 267:
#   Predicted next coordinate: [180.15884  66.20055]
#   True next coordinate: [180.  66.]
# Test Sequence 268:
#   Predicted next coordinate: [ 88.07807 101.02193]
#   True next coordinate: [ 88. 102.]
# Test Sequence 269:
#   Predicted next coordinate: [125.61584  52.17737]
#   True next coordinate: [125.  52.]
# Test Sequence 270:
#   Predicted next coordinate: [173.31673  81.81989]
#   True next coordinate: [171.  81.]
# Test Sequence 271:
#   Predicted next coordinate: [ 95.71128 109.58798]
#   True next coordinate: [ 95. 111.]
# Test Sequence 272:
#   Predicted next coordinate: [ 85.38685 134.09848]
#   True next coordinate: [ 92. 135.]
# Test Sequence 273:
#   Predicted next coordinate: [11.103725   3.8523006]
#   True next coordinate: [11.  5.]
# Test Sequence 274:
#   Predicted next coordinate: [ 73.80891  126.938736]
#   True next coordinate: [ 78. 127.]
# Test Sequence 275:
#   Predicted next coordinate: [194.45224  95.26648]
#   True next coordinate: [197.  96.]
# Test Sequence 276:
#   Predicted next coordinate: [109.90444 100.487  ]
#   True next coordinate: [111. 103.]
# Test Sequence 277:
#   Predicted next coordinate: [ 37.83905 156.14287]
#   True next coordinate: [ 39. 153.]
# Test Sequence 278:
#   Predicted next coordinate: [121.84259 123.42226]
#   True next coordinate: [122. 123.]
# Test Sequence 279:
#   Predicted next coordinate: [131.89864   77.427216]
#   True next coordinate: [131.  78.]
# Test Sequence 280:
#   Predicted next coordinate: [170.85266 131.23174]
#   True next coordinate: [169. 124.]
# Test Sequence 281:
#   Predicted next coordinate: [149.90474   76.338455]
#   True next coordinate: [149.  75.]
# Test Sequence 282:
#   Predicted next coordinate: [ 60.258163 166.17308 ]
#   True next coordinate: [ 67. 168.]
# Test Sequence 283:
#   Predicted next coordinate: [138.20404   83.578735]
#   True next coordinate: [140.  84.]
# Test Sequence 284:
#   Predicted next coordinate: [98.53768  13.155031]
#   True next coordinate: [95. 13.]
# Test Sequence 285:
#   Predicted next coordinate: [166.07855 186.20679]
#   True next coordinate: [169. 175.]
# Test Sequence 286:
#   Predicted next coordinate: [156.96266  81.58948]
#   True next coordinate: [155.  82.]
# Test Sequence 287:
#   Predicted next coordinate: [172.9525     8.987772]
#   True next coordinate: [171.  13.]
# Test Sequence 288:
#   Predicted next coordinate: [62.655983 13.438019]
#   True next coordinate: [65. 17.]
# Test Sequence 289:
#   Predicted next coordinate: [ 86.33577 100.01439]
#   True next coordinate: [ 86. 101.]
# Test Sequence 290:
#   Predicted next coordinate: [ 84.920746 141.48631 ]
#   True next coordinate: [ 89. 138.]
# Test Sequence 291:
#   Predicted next coordinate: [165.19711 142.31543]
#   True next coordinate: [162. 134.]
# Test Sequence 292:
#   Predicted next coordinate: [13.173138 16.761778]
#   True next coordinate: [12. 18.]
# Test Sequence 293:
#   Predicted next coordinate: [ 63.145767 183.56625 ]
#   True next coordinate: [ 69. 182.]
# Test Sequence 294:
#   Predicted next coordinate: [124.38996 100.82469]
#   True next coordinate: [125. 104.]
# Test Sequence 295:
#   Predicted next coordinate: [ 56.799038 173.43105 ]
#   True next coordinate: [ 62. 176.]
# Test Sequence 296:
#   Predicted next coordinate: [122.565186  78.50551 ]
#   True next coordinate: [120.  80.]
# Test Sequence 297:
#   Predicted next coordinate: [150.99724  61.17559]
#   True next coordinate: [149.  63.]
# Test Sequence 298:
#   Predicted next coordinate: [68.34666  8.21467]
#   True next coordinate: [72.  7.]
# Test Sequence 299:
#   Predicted next coordinate: [127.34838  57.44527]
#   True next coordinate: [129.  72.]
# Test Sequence 300:
#   Predicted next coordinate: [65.270744  14.1417675]
#   True next coordinate: [69. 14.]
# Test Sequence 301:
#   Predicted next coordinate: [143.66325   81.203316]
#   True next coordinate: [143.  82.]
# Test Sequence 302:
#   Predicted next coordinate: [77.58186  27.236933]
#   True next coordinate: [77. 25.]
# Test Sequence 303:
#   Predicted next coordinate: [171.54492   73.523705]
#   True next coordinate: [173.  73.]
# Test Sequence 304:
#   Predicted next coordinate: [ 65.54411 135.0822 ]
#   True next coordinate: [ 71. 135.]
# Test Sequence 305:
#   Predicted next coordinate: [ 72.54987  123.792145]
#   True next coordinate: [ 77. 125.]
# Test Sequence 306:
#   Predicted next coordinate: [159.55841  84.16972]
#   True next coordinate: [157.  85.]
# Test Sequence 307:
#   Predicted next coordinate: [145.54129  70.94804]
#   True next coordinate: [146.  68.]
# Test Sequence 308:
#   Predicted next coordinate: [160.41562  96.20567]
#   True next coordinate: [157.  98.]
# Test Sequence 309:
#   Predicted next coordinate: [124.30803  79.6499 ]
#   True next coordinate: [122.  82.]
# Test Sequence 310:
#   Predicted next coordinate: [85.47035   -2.7518005]
#   True next coordinate: [86.  1.]
# Test Sequence 311:
#   Predicted next coordinate: [197.49753   26.955637]
#   True next coordinate: [198.  40.]
# Test Sequence 312:
#   Predicted next coordinate: [172.05414   52.025063]
#   True next coordinate: [171.  55.]
# Test Sequence 313:
#   Predicted next coordinate: [121.29319 105.75868]
#   True next coordinate: [122. 109.]
# Test Sequence 314:
#   Predicted next coordinate: [104.70648 116.85603]
#   True next coordinate: [107. 117.]
# Test Sequence 315:
#   Predicted next coordinate: [ 1.5741005 36.144516 ]
#   True next coordinate: [ 2. 36.]
# Test Sequence 316:
#   Predicted next coordinate: [89.44703  92.536285]
#   True next coordinate: [91. 95.]
# Test Sequence 317:
#   Predicted next coordinate: [67.055405 78.637314]
#   True next coordinate: [70. 74.]
# Test Sequence 318:
#   Predicted next coordinate: [185.41492 193.6397 ]
#   True next coordinate: [199. 197.]
# Test Sequence 319:
#   Predicted next coordinate: [108.4785    16.302336]
#   True next coordinate: [101.  14.]
# Test Sequence 320:
#   Predicted next coordinate: [82.22918 72.97325]
#   True next coordinate: [80. 69.]
# Test Sequence 321:
#   Predicted next coordinate: [141.29434   -4.038025]
#   True next coordinate: [137.   1.]
# Test Sequence 322:
#   Predicted next coordinate: [98.13209  65.310196]
#   True next coordinate: [91. 67.]
# Test Sequence 323:
#   Predicted next coordinate: [143.95251   55.716118]
#   True next coordinate: [144.  58.]
# Test Sequence 324:
#   Predicted next coordinate: [ 88.41362 124.20473]
#   True next coordinate: [ 93. 125.]
# Test Sequence 325:
#   Predicted next coordinate: [155.16437   40.531136]
#   True next coordinate: [155.  43.]
# Test Sequence 326:
#   Predicted next coordinate: [147.91591  79.55153]
#   True next coordinate: [147.  80.]
# Test Sequence 327:
#   Predicted next coordinate: [154.71027   81.393265]
#   True next coordinate: [153.  82.]
# Test Sequence 328:
#   Predicted next coordinate: [129.26332  72.30498]
#   True next coordinate: [129.  71.]
# Test Sequence 329:
#   Predicted next coordinate: [126.843544  68.016785]
#   True next coordinate: [127.  66.]
# Test Sequence 330:
#   Predicted next coordinate: [166.21764 186.08656]
#   True next coordinate: [169. 175.]
# Test Sequence 331:
#   Predicted next coordinate: [119.53053   24.015827]
#   True next coordinate: [117.  23.]
# Test Sequence 332:
#   Predicted next coordinate: [152.14435   59.537785]
#   True next coordinate: [152.  61.]
# Test Sequence 333:
#   Predicted next coordinate: [101.69224  72.43591]
#   True next coordinate: [98. 72.]
# Test Sequence 334:
#   Predicted next coordinate: [152.34276   42.055885]
#   True next coordinate: [151.  45.]
# Test Sequence 335:
#   Predicted next coordinate: [157.82802  17.2012 ]
#   True next coordinate: [156.  15.]
# Test Sequence 336:
#   Predicted next coordinate: [167.29315   30.653204]
#   True next coordinate: [164.  36.]
# Test Sequence 337:
#   Predicted next coordinate: [148.75955   74.620026]
#   True next coordinate: [148.  73.]
# Test Sequence 338:
#   Predicted next coordinate: [143.58958  99.52922]
#   True next coordinate: [144.  99.]
# Test Sequence 339:
#   Predicted next coordinate: [116.48611 109.75154]
#   True next coordinate: [119. 114.]
# Test Sequence 340:
#   Predicted next coordinate: [109.1829  121.38196]
#   True next coordinate: [112. 121.]
# Test Sequence 341:
#   Predicted next coordinate: [145.65558  75.47011]
#   True next coordinate: [145.  77.]
# Test Sequence 342:
#   Predicted next coordinate: [186.21764 124.31593]
#   True next coordinate: [189. 119.]
# Test Sequence 343:
#   Predicted next coordinate: [118.2387 148.2854]
#   True next coordinate: [119. 146.]
# Test Sequence 344:
#   Predicted next coordinate: [182.5957  86.4385]
#   True next coordinate: [183.  87.]
# Test Sequence 345:
#   Predicted next coordinate: [123.89292  93.15868]
#   True next coordinate: [126.  93.]
# Test Sequence 346:
#   Predicted next coordinate: [135.29439   74.104935]
#   True next coordinate: [135.  72.]
# Test Sequence 347:
#   Predicted next coordinate: [ 92.37853 138.59718]
#   True next coordinate: [ 98. 135.]
# Test Sequence 348:
#   Predicted next coordinate: [194.5491    79.316864]
#   True next coordinate: [194.  79.]
# Test Sequence 349:
#   Predicted next coordinate: [ 98.106804 107.22702 ]
#   True next coordinate: [ 99. 106.]
# Test Sequence 350:
#   Predicted next coordinate: [41.082287 87.05169 ]
#   True next coordinate: [46. 82.]
# Test Sequence 351:
#   Predicted next coordinate: [121.7958   65.38454]
#   True next coordinate: [129.  80.]
# Test Sequence 352:
#   Predicted next coordinate: [125.115746  31.895111]
#   True next coordinate: [120.  34.]
# Test Sequence 353:
#   Predicted next coordinate: [87.82338 92.35428]
#   True next coordinate: [89. 95.]
# Test Sequence 354:
#   Predicted next coordinate: [158.65042  100.410645]
#   True next coordinate: [157.  95.]
# Test Sequence 355:
#   Predicted next coordinate: [179.02388  72.2035 ]
#   True next coordinate: [177.  71.]
# Test Sequence 356:
#   Predicted next coordinate: [72.747574 82.85731 ]
#   True next coordinate: [73. 81.]
# Test Sequence 357:
#   Predicted next coordinate: [ 55.65145 168.39095]
#   True next coordinate: [ 57. 168.]
# Test Sequence 358:
#   Predicted next coordinate: [122.722664  82.41837 ]
#   True next coordinate: [122.  84.]
# Test Sequence 359:
#   Predicted next coordinate: [93.34532  25.955236]
#   True next coordinate: [90. 21.]
# Test Sequence 360:
#   Predicted next coordinate: [101.64172   14.602007]
#   True next coordinate: [95. 13.]
# Test Sequence 361:
#   Predicted next coordinate: [193.6027    44.188213]
#   True next coordinate: [195.  54.]
# Test Sequence 362:
#   Predicted next coordinate: [170.1041    36.315342]
#   True next coordinate: [170.  37.]
# Test Sequence 363:
#   Predicted next coordinate: [104.021   119.96384]
#   True next coordinate: [103. 119.]
# Test Sequence 364:
#   Predicted next coordinate: [82.72118  19.705765]
#   True next coordinate: [85. 17.]
# Test Sequence 365:
#   Predicted next coordinate: [110.424576  86.92638 ]
#   True next coordinate: [112.  88.]
# Test Sequence 366:
#   Predicted next coordinate: [147.71432   74.611305]
#   True next coordinate: [148.  74.]
# Test Sequence 367:
#   Predicted next coordinate: [175.29103    8.955881]
#   True next coordinate: [176.   8.]
# Test Sequence 368:
#   Predicted next coordinate: [153.30385   40.578457]
#   True next coordinate: [152.  42.]
# Test Sequence 369:
#   Predicted next coordinate: [ 65.50421 180.93784]
#   True next coordinate: [ 66. 181.]
# Test Sequence 370:
#   Predicted next coordinate: [169.81964  17.01154]
#   True next coordinate: [164.  23.]
# Test Sequence 371:
#   Predicted next coordinate: [184.77222   32.526638]
#   True next coordinate: [179.  40.]
# Test Sequence 372:
#   Predicted next coordinate: [75.68527 74.03158]
#   True next coordinate: [75. 71.]
# Test Sequence 373:
#   Predicted next coordinate: [180.70935  113.395386]
#   True next coordinate: [180. 112.]
# Test Sequence 374:
#   Predicted next coordinate: [76.40293  87.023796]
#   True next coordinate: [76. 86.]
# Test Sequence 375:
#   Predicted next coordinate: [ 65.80575 151.82335]
#   True next coordinate: [ 71. 149.]
# Test Sequence 376:
#   Predicted next coordinate: [143.88205   86.144226]
#   True next coordinate: [144.  89.]
# Test Sequence 377:
#   Predicted next coordinate: [148.91179   29.127762]
#   True next coordinate: [145.  29.]
# Test Sequence 378:
#   Predicted next coordinate: [132.82657  92.87572]
#   True next coordinate: [133.  94.]
# Test Sequence 379:
#   Predicted next coordinate: [182.25114  73.69095]
#   True next coordinate: [183.  72.]
# Test Sequence 380:
#   Predicted next coordinate: [133.1516     8.556482]
#   True next coordinate: [124.  10.]
# Test Sequence 381:
#   Predicted next coordinate: [69.4992  82.28775]
#   True next coordinate: [67. 79.]
# Test Sequence 382:
#   Predicted next coordinate: [ 38.0532  167.97226]
#   True next coordinate: [ 40. 168.]
# Test Sequence 383:
#   Predicted next coordinate: [76.02931   5.492697]
#   True next coordinate: [79.  6.]
# Test Sequence 384:
#   Predicted next coordinate: [ 58.15554 153.37404]
#   True next coordinate: [ 62. 161.]
# Test Sequence 385:
#   Predicted next coordinate: [139.38892  71.29881]
#   True next coordinate: [139.  69.]
# Test Sequence 386:
#   Predicted next coordinate: [ 80.65555 139.82263]
#   True next coordinate: [ 83. 136.]
# Test Sequence 387:
#   Predicted next coordinate: [ 59.309875 109.29773 ]
#   True next coordinate: [ 62. 108.]
# Test Sequence 388:
#   Predicted next coordinate: [ 72.23614 106.95796]
#   True next coordinate: [ 74. 108.]
# Test Sequence 389:
#   Predicted next coordinate: [158.602     47.350754]
#   True next coordinate: [157.  50.]
# Test Sequence 390:
#   Predicted next coordinate: [104.03203   24.514833]
#   True next coordinate: [101.  23.]
# Test Sequence 391:
#   Predicted next coordinate: [177.64435   60.869568]
#   True next coordinate: [177.  62.]
# Test Sequence 392:
#   Predicted next coordinate: [178.89682   67.512344]
#   True next coordinate: [178.  66.]
# Test Sequence 393:
#   Predicted next coordinate: [173.40884  66.82535]
#   True next coordinate: [171.  65.]
# Test Sequence 394:
#   Predicted next coordinate: [159.45088   52.864883]
#   True next coordinate: [158.  58.]
# Test Sequence 395:
#   Predicted next coordinate: [ 65.87493 111.12126]
#   True next coordinate: [ 68. 109.]
# Test Sequence 396:
#   Predicted next coordinate: [128.92935   86.968765]
#   True next coordinate: [129.  88.]
# Test Sequence 397:
#   Predicted next coordinate: [162.3664   72.46701]
#   True next coordinate: [160.  71.]
# Test Sequence 398:
#   Predicted next coordinate: [181.27043  107.894714]
#   True next coordinate: [179. 110.]
# Test Sequence 399:
#   Predicted next coordinate: [164.76485  74.69494]
#   True next coordinate: [166.  75.]
# Test Sequence 400:
#   Predicted next coordinate: [196.5938    19.025969]
#   True next coordinate: [194.  27.]
# Test Sequence 401:
#   Predicted next coordinate: [ 57.629456 174.79851 ]
#   True next coordinate: [ 58. 178.]
# Test Sequence 402:
#   Predicted next coordinate: [83.48124 29.34069]
#   True next coordinate: [83. 25.]
# Test Sequence 403:
#   Predicted next coordinate: [160.52182   47.446476]
#   True next coordinate: [160.  51.]
# Test Sequence 404:
#   Predicted next coordinate: [156.46288  11.07654]
#   True next coordinate: [149.  15.]
# Test Sequence 405:
#   Predicted next coordinate: [192.75964   35.485313]
#   True next coordinate: [190.  45.]
# Test Sequence 406:
#   Predicted next coordinate: [ 78.70166 119.54083]
#   True next coordinate: [ 83. 119.]
# Test Sequence 407:
#   Predicted next coordinate: [143.12099   25.818195]
#   True next coordinate: [140.  25.]
# Test Sequence 408:
#   Predicted next coordinate: [82.40028 87.03196]
#   True next coordinate: [84. 92.]
# Test Sequence 409:
#   Predicted next coordinate: [ 75.07307  119.170715]
#   True next coordinate: [ 74. 122.]
# Test Sequence 410:
#   Predicted next coordinate: [177.98659  89.37734]
#   True next coordinate: [176.  89.]
# Test Sequence 411:
#   Predicted next coordinate: [150.41174  106.864685]
#   True next coordinate: [150. 105.]
# Test Sequence 412:
#   Predicted next coordinate: [97.44214  82.655914]
#   True next coordinate: [96. 83.]
# Test Sequence 413:
#   Predicted next coordinate: [73.69322  21.991573]
#   True next coordinate: [75. 19.]
# Test Sequence 414:
#   Predicted next coordinate: [190.95103   25.908852]
#   True next coordinate: [187.  34.]
# Test Sequence 415:
#   Predicted next coordinate: [111.51286  95.68123]
#   True next coordinate: [112.  99.]
# Test Sequence 416:
#   Predicted next coordinate: [119.049774  50.647804]
#   True next coordinate: [120.  51.]
# Test Sequence 417:
#   Predicted next coordinate: [88.84065  17.918839]
#   True next coordinate: [87. 15.]
# Test Sequence 418:
#   Predicted next coordinate: [ 46.62864 171.50162]
#   True next coordinate: [ 48. 173.]
# Test Sequence 419:
#   Predicted next coordinate: [141.20766  52.58667]
#   True next coordinate: [140.  56.]
# Test Sequence 420:
#   Predicted next coordinate: [115.928925  31.284063]
#   True next coordinate: [111.  31.]
# Test Sequence 421:
#   Predicted next coordinate: [142.92725 116.79878]
#   True next coordinate: [143. 117.]
# Test Sequence 422:
#   Predicted next coordinate: [180.41022  68.86323]
#   True next coordinate: [179.  68.]
# Test Sequence 423:
#   Predicted next coordinate: [ 82.48948 138.71391]
#   True next coordinate: [ 85. 135.]
# Test Sequence 424:
#   Predicted next coordinate: [ 86.52041 140.22964]
#   True next coordinate: [ 90. 137.]
# Test Sequence 425:
#   Predicted next coordinate: [124.54466  64.93837]
#   True next coordinate: [125.  63.]
# Test Sequence 426:
#   Predicted next coordinate: [ 61.026344 142.92116 ]
#   True next coordinate: [ 69. 148.]
# Test Sequence 427:
#   Predicted next coordinate: [ 48.574375 178.35489 ]
#   True next coordinate: [ 50. 181.]
# Test Sequence 428:
#   Predicted next coordinate: [173.07408 166.6838 ]
#   True next coordinate: [170. 154.]
# Test Sequence 429:
#   Predicted next coordinate: [ 97.658295 125.82373 ]
#   True next coordinate: [ 98. 126.]
# Test Sequence 430:
#   Predicted next coordinate: [121.18068  42.78888]
#   True next coordinate: [119.  43.]
# Test Sequence 431:
#   Predicted next coordinate: [125.341446  54.38585 ]
#   True next coordinate: [126.  54.]
# Test Sequence 432:
#   Predicted next coordinate: [73.32742  84.250244]
#   True next coordinate: [73. 83.]
# Test Sequence 433:
#   Predicted next coordinate: [104.27282  97.72591]
#   True next coordinate: [105. 101.]
# Test Sequence 434:
#   Predicted next coordinate: [69.7728   18.141161]
#   True next coordinate: [72. 18.]
# Test Sequence 435:
#   Predicted next coordinate: [164.1826   57.21457]
#   True next coordinate: [163.  60.]
# Test Sequence 436:
#   Predicted next coordinate: [134.19594  85.16258]
#   True next coordinate: [133.  87.]
# Test Sequence 437:
#   Predicted next coordinate: [172.00581  64.20163]
#   True next coordinate: [170.  65.]
# Test Sequence 438:
#   Predicted next coordinate: [157.28708 101.7345 ]
#   True next coordinate: [159. 100.]
# Test Sequence 439:
#   Predicted next coordinate: [189.72208  83.0112 ]
#   True next coordinate: [198.  81.]
# Test Sequence 440:
#   Predicted next coordinate: [ 87.675995 133.73398 ]
#   True next coordinate: [ 77. 115.]
# Test Sequence 441:
#   Predicted next coordinate: [173.3963  167.49239]
#   True next coordinate: [169. 153.]
# Test Sequence 442:
#   Predicted next coordinate: [127.16842  74.49687]
#   True next coordinate: [127.  75.]
# Test Sequence 443:
#   Predicted next coordinate: [181.04398   89.089066]
#   True next coordinate: [180.  89.]
# Test Sequence 444:
#   Predicted next coordinate: [135.12888 107.34245]
#   True next coordinate: [136. 110.]
# Test Sequence 445:
#   Predicted next coordinate: [ 73.8815 114.0751]
#   True next coordinate: [ 74. 114.]
# Test Sequence 446:
#   Predicted next coordinate: [-0.4713173 44.78081  ]
#   True next coordinate: [ 2. 43.]
# Test Sequence 447:
#   Predicted next coordinate: [115.0092  127.69104]
#   True next coordinate: [117. 127.]
# Test Sequence 448:
#   Predicted next coordinate: [174.45193   18.202532]
#   True next coordinate: [170.  26.]
# Test Sequence 449:
#   Predicted next coordinate: [158.74782  112.436874]
#   True next coordinate: [155. 107.]
# Test Sequence 450:
#   Predicted next coordinate: [151.86215  70.6434 ]
#   True next coordinate: [152.  70.]
# Test Sequence 451:
#   Predicted next coordinate: [172.5242  66.6883]
#   True next coordinate: [171.  68.]
# Test Sequence 452:
#   Predicted next coordinate: [148.14807  36.98117]
#   True next coordinate: [145.  38.]
# Test Sequence 453:
# ...
#   Predicted next coordinate: [183.48509  86.70209]
#   True next coordinate: [183.  87.]
# Test Sequence 4307:
#   Predicted next coordinate: [12.171177   6.8635807]
#   True next coordinate: [13.  8.]
# Test Sequence 4308:
#   Predicted next coordinate: [148.22556  87.07361]
#   True next coordinate: [146.  88.]
# Test Sequence 4309:
#   Predicted next coordinate: [ 58.20532 138.06432]
#   True next coordinate: [ 61. 139.]
# Test Sequence 4310:
#   Predicted next coordinate: [76.16955 86.19656]
#   True next coordinate: [76. 86.]
# Test Sequence 4311:
#   Predicted next coordinate: [101.31568   80.081665]
#   True next coordinate: [100.  81.]
# Test Sequence 4312:
#   Predicted next coordinate: [194.91592   19.120117]
#   True next coordinate: [194.  27.]
# Test Sequence 4313:
#   Predicted next coordinate: [163.18683   22.134907]
#   True next coordinate: [157.  26.]
# Test Sequence 4314:
#   Predicted next coordinate: [72.30294 97.59714]
#   True next coordinate: [75. 98.]
# Test Sequence 4315:
#   Predicted next coordinate: [101.989075  97.65228 ]
#   True next coordinate: [105.  98.]
# Test Sequence 4316:
#   Predicted next coordinate: [126.027954  76.03807 ]
#   True next coordinate: [124.  78.]
# Test Sequence 4317:
#   Predicted next coordinate: [64.78563   3.220436]
#   True next coordinate: [69.  2.]
# Test Sequence 4318:
#   Predicted next coordinate: [122.06099  66.83799]
#   True next coordinate: [123.  66.]
# Test Sequence 4319:
#   Predicted next coordinate: [3.1160393 8.260035 ]
#   True next coordinate: [ 2. 10.]
# Test Sequence 4320:
#   Predicted next coordinate: [128.88916  114.394775]
#   True next coordinate: [129. 118.]
# Test Sequence 4321:
#   Predicted next coordinate: [135.1811   101.897766]
#   True next coordinate: [137. 102.]
# Test Sequence 4322:
#   Predicted next coordinate: [115.4371   58.46029]
#   True next coordinate: [116.  57.]
# Test Sequence 4323:
#   Predicted next coordinate: [ 34.74146 178.92142]
#   True next coordinate: [ 40. 181.]
# Test Sequence 4324:
#   Predicted next coordinate: [105.244576 113.013245]
#   True next coordinate: [112. 128.]
# Test Sequence 4325:
#   Predicted next coordinate: [87.428795 18.157906]
#   True next coordinate: [90. 14.]
# Test Sequence 4326:
#   Predicted next coordinate: [110.8588    54.686928]
#   True next coordinate: [110.  55.]
# Test Sequence 4327:
#   Predicted next coordinate: [124.90936   18.752148]
#   True next coordinate: [119.  16.]
# Test Sequence 4328:
#   Predicted next coordinate: [196.419  100.2393]
#   True next coordinate: [199. 101.]
# Test Sequence 4329:
#   Predicted next coordinate: [36.041916   1.9774189]
#   True next coordinate: [35.  3.]
# Test Sequence 4330:
#   Predicted next coordinate: [197.87743   27.611176]
#   True next coordinate: [199.  42.]
# Test Sequence 4331:
#   Predicted next coordinate: [ 80.93078 133.50388]
#   True next coordinate: [ 84. 132.]
# Test Sequence 4332:
#   Predicted next coordinate: [129.16844  76.21022]
#   True next coordinate: [127.  77.]
# Test Sequence 4333:
#   Predicted next coordinate: [149.7817   41.93687]
#   True next coordinate: [147.  45.]
# Test Sequence 4334:
#   Predicted next coordinate: [44.54671  80.371796]
#   True next coordinate: [49. 76.]
# Test Sequence 4335:
#   Predicted next coordinate: [154.12698  69.25971]
#   True next coordinate: [153.  69.]
# Test Sequence 4336:
#   Predicted next coordinate: [158.65947   43.717346]
#   True next coordinate: [158.  46.]
# Test Sequence 4337:
#   Predicted next coordinate: [100.80739   90.895096]
#   True next coordinate: [99. 94.]
# Test Sequence 4338:
#   Predicted next coordinate: [139.47661   53.169025]
#   True next coordinate: [140.  55.]
# Test Sequence 4339:
#   Predicted next coordinate: [70.72039 97.63342]
#   True next coordinate: [76. 99.]
# Test Sequence 4340:
#   Predicted next coordinate: [73.91273 75.80872]
#   True next coordinate: [74. 71.]
# Test Sequence 4341:
#   Predicted next coordinate: [172.73088 144.86328]
#   True next coordinate: [175. 135.]
# Test Sequence 4342:
#   Predicted next coordinate: [162.61205 184.82635]
#   True next coordinate: [162. 172.]
# Test Sequence 4343:
#   Predicted next coordinate: [110.095245  91.18436 ]
#   True next coordinate: [110.  93.]
# Test Sequence 4344:
#   Predicted next coordinate: [192.24503   56.517143]
#   True next coordinate: [197.  66.]
# Test Sequence 4345:
#   Predicted next coordinate: [152.91248  88.00816]
#   True next coordinate: [151.  91.]
# Test Sequence 4346:
#   Predicted next coordinate: [94.201515 97.68686 ]
#   True next coordinate: [97. 98.]
# Test Sequence 4347:
#   Predicted next coordinate: [ 85.728294 141.52583 ]
#   True next coordinate: [ 90. 137.]
# Test Sequence 4348:
#   Predicted next coordinate: [119.843475  60.75152 ]
#   True next coordinate: [122.  61.]
# Test Sequence 4349:
#   Predicted next coordinate: [90.91267  31.662062]
#   True next coordinate: [89. 26.]
# Test Sequence 4350:
#   Predicted next coordinate: [140.44157 111.13805]
#   True next coordinate: [142. 113.]
# Test Sequence 4351:
#   Predicted next coordinate: [177.24567 118.26463]
#   True next coordinate: [175. 115.]
# Test Sequence 4352:
#   Predicted next coordinate: [167.72958 133.89479]
#   True next coordinate: [165. 126.]
# Test Sequence 4353:
#   Predicted next coordinate: [146.68379 120.06763]
#   True next coordinate: [145. 120.]
# Test Sequence 4354:
#   Predicted next coordinate: [118.92844  62.62385]
#   True next coordinate: [120.  64.]
# Test Sequence 4355:
#   Predicted next coordinate: [192.07095   15.864817]
#   True next coordinate: [194.  17.]
# Test Sequence 4356:
#   Predicted next coordinate: [134.44766 109.16223]
#   True next coordinate: [135. 110.]
# Test Sequence 4357:
#   Predicted next coordinate: [ 59.66172 158.42012]
#   True next coordinate: [ 66. 163.]
# Test Sequence 4358:
#   Predicted next coordinate: [108.738785  81.520996]
#   True next coordinate: [108.  81.]
# Test Sequence 4359:
#   Predicted next coordinate: [ 76.45483 138.01848]
#   True next coordinate: [ 79. 136.]
# Test Sequence 4360:
#   Predicted next coordinate: [70.84774  13.611637]
#   True next coordinate: [73. 15.]
# Test Sequence 4361:
#   Predicted next coordinate: [149.85597  75.49998]
#   True next coordinate: [149.  76.]
# Test Sequence 4362:
#   Predicted next coordinate: [177.335     80.525406]
#   True next coordinate: [174.  80.]
# Test Sequence 4363:
#   Predicted next coordinate: [186.48222  61.53306]
#   True next coordinate: [189.  64.]
# Test Sequence 4364:
#   Predicted next coordinate: [148.10857 121.52794]
#   True next coordinate: [146. 122.]
# Test Sequence 4365:
#   Predicted next coordinate: [152.83333 125.55524]
#   True next coordinate: [150. 123.]
# Test Sequence 4366:
#   Predicted next coordinate: [115.22285  38.92286]
#   True next coordinate: [113.  39.]
# Test Sequence 4367:
#   Predicted next coordinate: [193.41573   19.037802]
#   True next coordinate: [193.  28.]
# Test Sequence 4368:
#   Predicted next coordinate: [112.15996 124.91997]
#   True next coordinate: [115. 123.]
# Test Sequence 4369:
#   Predicted next coordinate: [12.763017   2.6688023]
#   True next coordinate: [14.  3.]
# Test Sequence 4370:
#   Predicted next coordinate: [147.33539 105.59546]
#   True next coordinate: [149. 106.]
# Test Sequence 4371:
#   Predicted next coordinate: [ 60.016758 134.75446 ]
#   True next coordinate: [ 64. 136.]
# Test Sequence 4372:
#   Predicted next coordinate: [78.65699 73.71787]
#   True next coordinate: [77. 69.]
# Test Sequence 4373:
#   Predicted next coordinate: [ 68.24767 181.7236 ]
#   True next coordinate: [ 69. 183.]
# Test Sequence 4374:
#   Predicted next coordinate: [107.575745  83.125305]
#   True next coordinate: [107.  83.]
# Test Sequence 4375:
#   Predicted next coordinate: [118.80224  98.30374]
#   True next coordinate: [119. 102.]
# Test Sequence 4376:
#   Predicted next coordinate: [130.58401   14.418519]
#   True next coordinate: [124.  11.]
# Test Sequence 4377:
#   Predicted next coordinate: [139.6759    55.365597]
#   True next coordinate: [139.  57.]
# Test Sequence 4378:
#   Predicted next coordinate: [115.788864  19.504604]
#   True next coordinate: [107.  17.]
# Test Sequence 4379:
#   Predicted next coordinate: [137.17976    7.259138]
#   True next coordinate: [129.   9.]
# Test Sequence 4380:
#   Predicted next coordinate: [125.05879   68.823494]
#   True next coordinate: [125.  68.]
# Test Sequence 4381:
#   Predicted next coordinate: [67.73394 17.72445]
#   True next coordinate: [70. 18.]
# Test Sequence 4382:
#   Predicted next coordinate: [144.62563   24.480688]
#   True next coordinate: [140.  25.]
# Test Sequence 4383:
#   Predicted next coordinate: [94.201515 97.68686 ]
#   True next coordinate: [96. 98.]
# Test Sequence 4384:
#   Predicted next coordinate: [176.77267   15.935073]
#   True next coordinate: [172.  24.]
# Test Sequence 4385:
#   Predicted next coordinate: [ 96.6202  109.50961]
#   True next coordinate: [ 98. 110.]
# Test Sequence 4386:
#   Predicted next coordinate: [98.97314 89.01877]
#   True next coordinate: [99. 92.]
# Test Sequence 4387:
#   Predicted next coordinate: [ 62.166992 149.82993 ]
#   True next coordinate: [ 67. 148.]
# Test Sequence 4388:
#   Predicted next coordinate: [184.81158   19.073109]
#   True next coordinate: [180.  26.]
# Test Sequence 4389:
#   Predicted next coordinate: [140.75764   42.390984]
#   True next coordinate: [138.  46.]
# Test Sequence 4390:
#   Predicted next coordinate: [184.22359 106.46417]
#   True next coordinate: [184. 105.]
# Test Sequence 4391:
#   Predicted next coordinate: [105.27587  79.47191]
#   True next coordinate: [105.  81.]
# Test Sequence 4392:
#   Predicted next coordinate: [114.05336 100.31122]
#   True next coordinate: [116. 105.]
# Test Sequence 4393:
#   Predicted next coordinate: [196.53578  83.7544 ]
#   True next coordinate: [196.  84.]
# Test Sequence 4394:
#   Predicted next coordinate: [ 41.89042 161.66763]
#   True next coordinate: [ 43. 160.]
# Test Sequence 4395:
#   Predicted next coordinate: [ 55.584297 173.67557 ]
#   True next coordinate: [ 56. 176.]
# Test Sequence 4396:
#   Predicted next coordinate: [107.72331 111.49643]
#   True next coordinate: [111. 112.]
# Test Sequence 4397:
#   Predicted next coordinate: [124.5025  139.49373]
#   True next coordinate: [125. 134.]
# Test Sequence 4398:
#   Predicted next coordinate: [ 99.98788 106.36319]
#   True next coordinate: [102. 107.]
# Test Sequence 4399:
#   Predicted next coordinate: [13.000268  7.848875]
#   True next coordinate: [14.  9.]
# Test Sequence 4400:
#   Predicted next coordinate: [ 73.41228  111.530106]
#   True next coordinate: [ 77. 112.]
# Test Sequence 4401:
#   Predicted next coordinate: [182.82779   37.246944]
#   True next coordinate: [178.  44.]
# Test Sequence 4402:
#   Predicted next coordinate: [131.55663  81.03779]
#   True next coordinate: [130.  83.]
# Test Sequence 4403:
#   Predicted next coordinate: [ 75.96817 122.06012]
#   True next coordinate: [ 78. 121.]
# Test Sequence 4404:
#   Predicted next coordinate: [ 68.3493 182.5208]
#   True next coordinate: [ 66. 185.]
# Test Sequence 4405:
#   Predicted next coordinate: [192.7122   23.46687]
#   True next coordinate: [190.  33.]
# Test Sequence 4406:
#   Predicted next coordinate: [ 70.76091 107.65115]
#   True next coordinate: [ 74. 108.]
# Test Sequence 4407:
#   Predicted next coordinate: [164.3878  185.11084]
#   True next coordinate: [171. 175.]
# Test Sequence 4408:
#   Predicted next coordinate: [ 60.623444 112.395294]
#   True next coordinate: [ 63. 114.]
# Test Sequence 4409:
#   Predicted next coordinate: [156.42738 107.16498]
#   True next coordinate: [156. 105.]
# Test Sequence 4410:
#   Predicted next coordinate: [182.91556 103.50127]
#   True next coordinate: [184. 105.]
# Test Sequence 4411:
#   Predicted next coordinate: [ 87.474335 131.10219 ]
#   True next coordinate: [ 91. 131.]
# Test Sequence 4412:
#   Predicted next coordinate: [101.44894   18.504408]
#   True next coordinate: [102.  15.]
# Test Sequence 4413:
#   Predicted next coordinate: [183.36014   39.319695]
#   True next coordinate: [179.  46.]
# Test Sequence 4414:
#   Predicted next coordinate: [146.5341    68.715256]
#   True next coordinate: [145.  70.]
# Test Sequence 4415:
#   Predicted next coordinate: [123.499374 144.79442 ]
#   True next coordinate: [122. 140.]
# Test Sequence 4416:
#   Predicted next coordinate: [141.38956  69.72307]
#   True next coordinate: [144.  69.]
# Test Sequence 4417:
#   Predicted next coordinate: [170.41815  65.16239]
#   True next coordinate: [168.  65.]
# Test Sequence 4418:
#   Predicted next coordinate: [170.58215  74.564  ]
#   True next coordinate: [166.  75.]
# Test Sequence 4419:
#   Predicted next coordinate: [131.72829  58.00392]
#   True next coordinate: [132.  58.]
# Test Sequence 4420:
#   Predicted next coordinate: [146.63257   61.575302]
#   True next coordinate: [148.  62.]
# Test Sequence 4421:
#   Predicted next coordinate: [182.20833  67.41814]
#   True next coordinate: [183.  67.]
# Test Sequence 4422:
#   Predicted next coordinate: [164.87688    5.930279]
#   True next coordinate: [162.  10.]
# Test Sequence 4423:
#   Predicted next coordinate: [ 76.956985 193.33466 ]
#   True next coordinate: [ 77. 197.]
# Test Sequence 4424:
#   Predicted next coordinate: [ 9.418579 10.660496]
#   True next coordinate: [ 8. 12.]
# Test Sequence 4425:
#   Predicted next coordinate: [161.05028   14.783562]
#   True next coordinate: [155.  20.]
# Test Sequence 4426:
#   Predicted next coordinate: [ 84.920746 141.48631 ]
#   True next coordinate: [ 88. 138.]
# Test Sequence 4427:
#   Predicted next coordinate: [ 58.019455 177.2812  ]
#   True next coordinate: [ 57. 178.]
# Test Sequence 4428:
#   Predicted next coordinate: [166.08507  77.6051 ]
#   True next coordinate: [167.  78.]
# Test Sequence 4429:
#   Predicted next coordinate: [167.59798  29.5098 ]
#   True next coordinate: [163.  34.]
# Test Sequence 4430:
#   Predicted next coordinate: [124.09048     -0.24236488]
#   True next coordinate: [114.   1.]
# Test Sequence 4431:
#   Predicted next coordinate: [129.51227   59.546715]
#   True next coordinate: [130.  59.]
# Test Sequence 4432:
#   Predicted next coordinate: [122.594215  73.72194 ]
#   True next coordinate: [120.  76.]
# Test Sequence 4433:
#   Predicted next coordinate: [114.58674  49.1511 ]
#   True next coordinate: [115.  47.]
# Test Sequence 4434:
#   Predicted next coordinate: [11.038416  5.170721]
#   True next coordinate: [12.  7.]
# Test Sequence 4435:
#   Predicted next coordinate: [184.50706   54.889404]
#   True next coordinate: [184.  59.]
# Test Sequence 4436:
#   Predicted next coordinate: [131.89864   77.427216]
#   True next coordinate: [132.  79.]
# Test Sequence 4437:
#   Predicted next coordinate: [139.6759    55.365597]
#   True next coordinate: [140.  56.]
# Test Sequence 4438:
#   Predicted next coordinate: [ 41.447865 192.93059 ]
#   True next coordinate: [ 45. 198.]
# Test Sequence 4439:
#   Predicted next coordinate: [ 74.349495 189.524   ]
#   True next coordinate: [ 75. 191.]
# Test Sequence 4440:
#   Predicted next coordinate: [98.55573 75.18381]
#   True next coordinate: [96. 75.]
# Test Sequence 4441:
#   Predicted next coordinate: [93.065186 99.52716 ]
#   True next coordinate: [ 93. 101.]
# Test Sequence 4442:
#   Predicted next coordinate: [129.46373  45.08706]
#   True next coordinate: [131.  46.]
# Test Sequence 4443:
#   Predicted next coordinate: [ 89.88568 134.77042]
#   True next coordinate: [ 96. 134.]
# Test Sequence 4444:
#   Predicted next coordinate: [ 92.33127 126.35112]
#   True next coordinate: [ 98. 126.]
# Test Sequence 4445:
#   Predicted next coordinate: [145.00732  116.515945]
#   True next coordinate: [145. 116.]
# Test Sequence 4446:
#   Predicted next coordinate: [101.7028   83.34425]
#   True next coordinate: [101.  85.]
# Test Sequence 4447:
#   Predicted next coordinate: [52.121292 82.21989 ]
#   True next coordinate: [56. 82.]
# Test Sequence 4448:
#   Predicted next coordinate: [131.16061  77.94313]
#   True next coordinate: [130.  78.]
# Test Sequence 4449:
#   Predicted next coordinate: [58.239754  8.822908]
#   True next coordinate: [60.  9.]
# Test Sequence 4450:
#   Predicted next coordinate: [180.70935  113.395386]
#   True next coordinate: [180. 113.]
# Test Sequence 4451:
#   Predicted next coordinate: [193.03749  70.96284]
#   True next coordinate: [192.  71.]
# Test Sequence 4452:
#   Predicted next coordinate: [159.84853  111.256454]
#   True next coordinate: [159. 110.]
# Test Sequence 4453:
#   Predicted next coordinate: [115.47248 132.92545]
#   True next coordinate: [116. 132.]
# Test Sequence 4454:
#   Predicted next coordinate: [154.71027   81.393265]
#   True next coordinate: [152.  82.]

# %%
def pred_next_coord(sequence):
    seq_tensor = torch.tensor(sequence, dtype=torch.float32).unsqueeze(0)
    seq_length = torch.tensor([seq_tensor.size(1)])
    model.eval()

    with torch.no_grad():
        predicted_next_coord = model(seq_tensor, seq_length)

    print("Next coordinate predicted: ", predicted_next_coord.squeeze().numpy())

# %%
sequence = ((88, 95), (77, 99), (77, 100))


pred_next_coord(sequence)
# Out:
# Next coordinate predicted:  [73.32224  97.934845]
